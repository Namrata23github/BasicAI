# %%
import pandas as pd, numpy as np, seaborn as sns
from matplotlib import pyplot as plt

# %%
LogisticRegression

# %%
wdata.var()
# Out:
# Respondent              3350.000000
# Product_Quality            1.912728
# E_Commerce                 0.591231
# Technical_Support          2.739649
# Complaint_Resolution       1.464014
# Advertising                1.315746
# Product_Line               1.735553
# Salesforce_Image           1.273664
# Competitive_Pricing        2.500361
# Warranty&Claims            0.766229
# Packaging                  2.238030
# Order&Billing              0.831594
# Price_Flexibility          1.422416
# Delivery_Speed             0.561552
# dtype: float64

# %%
wdata.corr()
# Out:
#                       Respondent  Product_Quality  E_Commerce  \
# Respondent              1.000000         0.069431    0.098664
# Product_Quality         0.069431         1.000000   -0.034316
# E_Commerce              0.098664        -0.034316    1.000000
# Technical_Support      -0.069622         0.086604    0.040514
# Complaint_Resolution   -0.104256         0.089551    0.191758
# Advertising             0.064431        -0.053901    0.505198
# Product_Line            0.002491         0.509295    0.077115
# Salesforce_Image        0.101440        -0.116104    0.788225
# Competitive_Pricing    -0.038424        -0.448112    0.177294
# Warranty&Claims        -0.003655         0.109202    0.103102
# Packaging               0.006247         0.135629   -0.041005
# Order&Billing          -0.051688         0.083037    0.216890
# Price_Flexibility      -0.154809        -0.487213    0.186243
# Delivery_Speed         -0.125081         0.066617    0.240808
#
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(wdata.corr(),annot=True,cmap='rainbow')

# %%
x=wdata.iloc[0:,1:]

# %%
from sklearn.decomposition import PCA

# %%
pcaModel = PCA(n_components=13)

# %%
pcaModel.fit(x)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=13, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
pcaModel.explained_variance_
# Out:
# array([5.03307718, 4.17009745, 3.01231876, 2.08232407, 1.7598727 ,
#        1.21633739, 0.73686911, 0.56591811, 0.27123224, 0.18682994,
#        0.1684795 , 0.14154236, 0.00786803])

# %%
pcaModel.explained_variance_ratio_
# Out:
# array([0.26007016, 0.2154781 , 0.15565313, 0.10759826, 0.09093649,
#        0.06285083, 0.03807565, 0.02924223, 0.01401517, 0.00965391,
#        0.00870571, 0.0073138 , 0.00040656])

# %%
np.cumsum(pcaModel.explained_variance_ratio_*100)
# Out:
# array([ 26.00701604,  47.55482614,  63.12013928,  73.87996544,
#         82.9736145 ,  89.25869716,  93.06626181,  95.99048508,
#         97.39200169,  98.35739305,  99.22796366,  99.95934413,
#        100.        ])

# %%
pcaModel_8c = PCA(n_components=8)

# %%
pcaModel_8c.fit(x)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=8, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
pd.DataFrame(pcaModel_8c.components_)
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.430251  0.006899 -0.312715 -0.233400 -0.012857 -0.492678  0.017316
# 1  0.196277 -0.200681 -0.268891 -0.404501 -0.322217 -0.092655 -0.365899
# 2  0.099156  0.044335 -0.776101  0.198956  0.137399  0.173937  0.063635
# 3  0.076198  0.118380 -0.213915  0.119406  0.112076  0.192348  0.132366
# 4  0.211077  0.329201  0.005544 -0.365592  0.503231 -0.080994  0.516619
# 5 -0.605727 -0.004132  0.021772 -0.044879  0.172338 -0.164791  0.087911
# 6  0.585560 -0.029479  0.050344 -0.007888  0.085386 -0.553143 -0.041339
# 7 -0.007170 -0.386772  0.087039 -0.027190  0.734403  0.127772 -0.485203
#
#          7         8         9         10        11        12
# 0  0.521613 -0.171361 -0.158096 -0.148671  0.227478 -0.138147
# 1 -0.298209 -0.151451 -0.047960 -0.287778 -0.412694 -0.267749
# 2 -0.100831 -0.339734  0.341353  0.146381  0.097343  0.141752
# 3 -0.074622 -0.114659 -0.905005  0.039584 -0.106043  0.050216
# ...

# %%
pd.DataFrame(pcaModel_8c.transform(x))
# Out:
#             0         1         2         3         4         5         6  \
# 0    1.261857  0.035032  2.612028  1.666938  0.306171  0.139477  1.365607
# 1   -2.300377  0.892197  0.623032  1.530609 -2.834839  0.325148 -0.488818
# 2   -3.109430 -0.222265  0.587819  1.384567  0.587419  0.970545  0.568521
# 3    2.074414 -0.086868 -3.217971  0.226088  0.212849 -0.138574 -0.557674
# 4   -0.565644  1.954175 -0.640682  0.432996 -0.759454 -1.043056  0.097709
# 5    2.781835  1.443070  2.347681 -4.380300 -0.120871 -0.169832 -0.725870
# 6    5.066692  2.860277 -2.626935  1.066504  0.603395 -0.353614  0.722793
# 7    2.923907 -0.166893  0.678230 -0.096956 -0.535957  1.788091  1.258661
# 8    2.214625 -2.535526 -0.006154  0.508384 -1.673567 -0.322872 -0.992066
# 9    1.664601 -2.058127  0.536481 -0.030750 -0.256265  0.163342 -0.491018
# 10  -1.038227  1.630628  1.154226 -1.942583 -0.309511 -0.930938 -0.796981
# 11   2.694319 -0.643172 -1.483962 -1.395147  1.799874  0.817567 -0.260629
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
fdata = pd.read_csv('flower.csv', sep='\t')
x = fdata.iloc[0:,0:-1]
y =fdata.Species
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
modelsteps=[('Standardize',StandardScaler()),('knn',KNeighborsClassifier(n_neighbors=3))]

# %%
pipeModel = Pipeline(steps=modelsteps)
pipeModel.fit(x_train,y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('Standardize', StandardScaler(copy=True, with_mean=True, with_std=True)), ('knn', KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#            weights='uniform'))])

# %%
pipeModel.predict(x_test)
# Out:
# array([2, 2, 0, 0, 2, 1, 2, 1, 2, 2, 0, 0, 0, 1, 1, 1, 0, 2, 0, 0, 1, 1,
#        1, 1, 2, 1, 2, 2, 2, 2, 2, 1, 0, 2, 2, 2, 2, 2])
